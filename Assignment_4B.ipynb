# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepgoku/Assignment4A/blob/master/Assignment_4B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Libraries and modules**

# %% [markdown]
# # GRADCAM

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# Training parameters
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 20:
        lr *= 1e-2
    elif epoch > 50:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

    


def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth) % 6 != 0:
        raise ValueError('depth should be 6n (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth ) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            if stack > 0:
                y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])
model.summary()
print(model_type)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 32, 32, 16)   448         input_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 32, 32, 16)   64          conv2d_174[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 32, 32, 16)   0           batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 32, 32, 16)   2320        activation_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 32, 32, 16)   64          conv2d_175[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 32, 32, 16)   0           batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 32, 32, 16)   0           activation_167[0][0]
#                                                                  activation_168[0][0]
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, 32, 32, 16)   0           add_79[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 32, 32, 16)   2320        activation_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 32, 32, 16)   64          conv2d_176[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 32, 32, 16)   0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 32, 32, 16)   0           activation_169[0][0]
#                                                                  activation_170[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 32, 32, 16)   0           add_80[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 32, 32, 16)   2320        activation_171[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 32, 32, 16)   64          conv2d_177[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 32, 32, 16)   0           batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 32, 32, 16)   0           activation_171[0][0]
#                                                                  activation_172[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 32, 32, 16)   0           add_81[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 16, 16, 32)   4640        activation_173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 16, 16, 32)   128         conv2d_178[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 16, 16, 32)   0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 16, 16, 32)   9248        activation_174[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 16, 16, 32)   544         activation_173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 16, 16, 32)   128         conv2d_179[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 16, 16, 32)   0           conv2d_180[0][0]
#                                                                  batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 16, 16, 32)   0           add_82[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 16, 16, 32)   9248        activation_175[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 16, 16, 32)   128         conv2d_181[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 16, 16, 32)   0           batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 16, 16, 32)   9248        activation_176[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 16, 16, 32)   128         conv2d_182[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 16, 16, 32)   0           activation_175[0][0]
#                                                                  batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 16, 16, 32)   0           add_83[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 16, 16, 32)   9248        activation_177[0][0]
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 16, 16, 32)   128         conv2d_183[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 16, 16, 32)   0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 16, 16, 32)   9248        activation_178[0][0]
# __________________________________________________________________________________________________
# batch_normalization_163 (BatchN (None, 16, 16, 32)   128         conv2d_184[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 16, 16, 32)   0           activation_177[0][0]
#                                                                  batch_normalization_163[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 16, 16, 32)   0           add_84[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 8, 8, 64)     18496       activation_179[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 8, 8, 64)     256         conv2d_185[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 8, 8, 64)     0           batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 8, 8, 64)     36928       activation_180[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 8, 8, 64)     2112        activation_179[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 8, 8, 64)     256         conv2d_186[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 8, 8, 64)     0           conv2d_187[0][0]
#                                                                  batch_normalization_165[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 8, 8, 64)     0           add_85[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 8, 8, 64)     36928       activation_181[0][0]
# __________________________________________________________________________________________________
# batch_normalization_166 (BatchN (None, 8, 8, 64)     256         conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 8, 8, 64)     0           batch_normalization_166[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 8, 8, 64)     36928       activation_182[0][0]
# __________________________________________________________________________________________________
# batch_normalization_167 (BatchN (None, 8, 8, 64)     256         conv2d_189[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 8, 8, 64)     0           activation_181[0][0]
#                                                                  batch_normalization_167[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 8, 8, 64)     0           add_86[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 8, 8, 64)     36928       activation_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_168 (BatchN (None, 8, 8, 64)     256         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 8, 8, 64)     0           batch_normalization_168[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 8, 8, 64)     36928       activation_184[0][0]
# __________________________________________________________________________________________________
# batch_normalization_169 (BatchN (None, 8, 8, 64)     256         conv2d_191[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, 8, 8, 64)     0           activation_183[0][0]
#                                                                  batch_normalization_169[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 8, 8, 64)     0           add_87[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, 1, 1, 64)     0           activation_185[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 64)           0           average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 10)           650         flatten_11[0][0]
# ==================================================================================================
# Total params: 267,290
# Trainable params: 266,010
# Non-trainable params: 1,280
# __________________________________________________________________________________________________
# ResNet18v1
# Using real-time data augmentation.
# Epoch 1/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 63s 40ms/step - loss: 1.5453 - acc: 0.4946 - val_loss: 1.3767 - val_acc: 0.5588
#
# Epoch 00001: val_acc improved from -inf to 0.55880, saving model to /content/saved_models/cifar10_ResNet18v1_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 49s 32ms/step - loss: 1.1798 - acc: 0.6329 - val_loss: 1.4082 - val_acc: 0.5790
#
# Epoch 00002: val_acc improved from 0.55880 to 0.57900, saving model to /content/saved_models/cifar10_ResNet18v1_model.002.h5
# Epoch 3/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 49s 32ms/step - loss: 1.0212 - acc: 0.6958 - val_loss: 1.3770 - val_acc: 0.6163
#
# Epoch 00003: val_acc improved from 0.57900 to 0.61630, saving model to /content/saved_models/cifar10_ResNet18v1_model.003.h5
# Epoch 4/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.9374 - acc: 0.7273 - val_loss: 1.6327 - val_acc: 0.5572
#
# Epoch 00004: val_acc did not improve from 0.61630
# Epoch 5/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.8715 - acc: 0.7544 - val_loss: 1.4532 - val_acc: 0.6263
#
# Epoch 00005: val_acc improved from 0.61630 to 0.62630, saving model to /content/saved_models/cifar10_ResNet18v1_model.005.h5
# Epoch 6/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.8268 - acc: 0.7691 - val_loss: 0.8468 - val_acc: 0.7671
#
# Epoch 00006: val_acc improved from 0.62630 to 0.76710, saving model to /content/saved_models/cifar10_ResNet18v1_model.006.h5
# Epoch 7/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.7907 - acc: 0.7849 - val_loss: 1.1347 - val_acc: 0.7036
#
# Epoch 00007: val_acc did not improve from 0.76710
# Epoch 8/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.7621 - acc: 0.7972 - val_loss: 1.1641 - val_acc: 0.7034
#
# Epoch 00008: val_acc did not improve from 0.76710
# Epoch 9/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.7434 - acc: 0.8026 - val_loss: 0.9263 - val_acc: 0.7526
#
# Epoch 00009: val_acc did not improve from 0.76710
# Epoch 10/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.7206 - acc: 0.8142 - val_loss: 0.8711 - val_acc: 0.7675
#
# Epoch 00010: val_acc improved from 0.76710 to 0.76750, saving model to /content/saved_models/cifar10_ResNet18v1_model.010.h5
# Epoch 11/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.7004 - acc: 0.8214 - val_loss: 0.7832 - val_acc: 0.7985
#
# Epoch 00011: val_acc improved from 0.76750 to 0.79850, saving model to /content/saved_models/cifar10_ResNet18v1_model.011.h5
# Epoch 12/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.6873 - acc: 0.8259 - val_loss: 0.9998 - val_acc: 0.7545
#
# Epoch 00012: val_acc did not improve from 0.79850
# Epoch 13/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.6746 - acc: 0.8302 - val_loss: 0.9247 - val_acc: 0.7583
#
# Epoch 00013: val_acc did not improve from 0.79850
# Epoch 14/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.6647 - acc: 0.8353 - val_loss: 0.8076 - val_acc: 0.7910
#
# Epoch 00014: val_acc did not improve from 0.79850
# Epoch 15/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.6482 - acc: 0.8406 - val_loss: 0.8185 - val_acc: 0.7898
#
# Epoch 00015: val_acc did not improve from 0.79850
# Epoch 16/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.6388 - acc: 0.8450 - val_loss: 0.8901 - val_acc: 0.7635
#
# Epoch 00016: val_acc did not improve from 0.79850
# Epoch 17/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.6380 - acc: 0.8450 - val_loss: 0.9893 - val_acc: 0.7532
#
# Epoch 00017: val_acc did not improve from 0.79850
# Epoch 18/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.6274 - acc: 0.8496 - val_loss: 0.8341 - val_acc: 0.7857
#
# Epoch 00018: val_acc did not improve from 0.79850
# Epoch 19/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.6181 - acc: 0.8534 - val_loss: 0.7290 - val_acc: 0.8203
#
# Epoch 00019: val_acc improved from 0.79850 to 0.82030, saving model to /content/saved_models/cifar10_ResNet18v1_model.019.h5
# Epoch 20/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.6167 - acc: 0.8534 - val_loss: 0.8890 - val_acc: 0.7756
#
# Epoch 00020: val_acc did not improve from 0.82030
# Epoch 21/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.6104 - acc: 0.8567 - val_loss: 0.7096 - val_acc: 0.8307
#
# Epoch 00021: val_acc improved from 0.82030 to 0.83070, saving model to /content/saved_models/cifar10_ResNet18v1_model.021.h5
# Epoch 22/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.5523 - acc: 0.8782 - val_loss: 0.6092 - val_acc: 0.8601
#
# Epoch 00022: val_acc improved from 0.83070 to 0.86010, saving model to /content/saved_models/cifar10_ResNet18v1_model.022.h5
# Epoch 23/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.5221 - acc: 0.8874 - val_loss: 0.5907 - val_acc: 0.8661
#
# Epoch 00023: val_acc improved from 0.86010 to 0.86610, saving model to /content/saved_models/cifar10_ResNet18v1_model.023.h5
# Epoch 24/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.5111 - acc: 0.8920 - val_loss: 0.5852 - val_acc: 0.8687
#
# Epoch 00024: val_acc improved from 0.86610 to 0.86870, saving model to /content/saved_models/cifar10_ResNet18v1_model.024.h5
# Epoch 25/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.5028 - acc: 0.8952 - val_loss: 0.5771 - val_acc: 0.8714
#
# Epoch 00025: val_acc improved from 0.86870 to 0.87140, saving model to /content/saved_models/cifar10_ResNet18v1_model.025.h5
# Epoch 26/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4975 - acc: 0.8959 - val_loss: 0.5721 - val_acc: 0.8726
#
# Epoch 00026: val_acc improved from 0.87140 to 0.87260, saving model to /content/saved_models/cifar10_ResNet18v1_model.026.h5
# Epoch 27/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4885 - acc: 0.8980 - val_loss: 0.5690 - val_acc: 0.8724
#
# Epoch 00027: val_acc did not improve from 0.87260
# Epoch 28/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4825 - acc: 0.8987 - val_loss: 0.5648 - val_acc: 0.8737
#
# Epoch 00028: val_acc improved from 0.87260 to 0.87370, saving model to /content/saved_models/cifar10_ResNet18v1_model.028.h5
# Epoch 29/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.4813 - acc: 0.9021 - val_loss: 0.5612 - val_acc: 0.8759
#
# Epoch 00029: val_acc improved from 0.87370 to 0.87590, saving model to /content/saved_models/cifar10_ResNet18v1_model.029.h5
# Epoch 30/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4803 - acc: 0.9021 - val_loss: 0.5573 - val_acc: 0.8769
#
# Epoch 00030: val_acc improved from 0.87590 to 0.87690, saving model to /content/saved_models/cifar10_ResNet18v1_model.030.h5
# Epoch 31/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4700 - acc: 0.9037 - val_loss: 0.5573 - val_acc: 0.8783
#
# Epoch 00031: val_acc improved from 0.87690 to 0.87830, saving model to /content/saved_models/cifar10_ResNet18v1_model.031.h5
# Epoch 32/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4739 - acc: 0.9033 - val_loss: 0.5537 - val_acc: 0.8783
#
# Epoch 00032: val_acc did not improve from 0.87830
# Epoch 33/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.4692 - acc: 0.9055 - val_loss: 0.5533 - val_acc: 0.8783
#
# Epoch 00033: val_acc did not improve from 0.87830
# Epoch 34/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4657 - acc: 0.9055 - val_loss: 0.5501 - val_acc: 0.8790
#
# Epoch 00034: val_acc improved from 0.87830 to 0.87900, saving model to /content/saved_models/cifar10_ResNet18v1_model.034.h5
# Epoch 35/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.4640 - acc: 0.9064 - val_loss: 0.5500 - val_acc: 0.8785
#
# Epoch 00035: val_acc did not improve from 0.87900
# Epoch 36/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4601 - acc: 0.9059 - val_loss: 0.5473 - val_acc: 0.8794
#
# Epoch 00036: val_acc improved from 0.87900 to 0.87940, saving model to /content/saved_models/cifar10_ResNet18v1_model.036.h5
# Epoch 37/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4596 - acc: 0.9072 - val_loss: 0.5481 - val_acc: 0.8785
#
# Epoch 00037: val_acc did not improve from 0.87940
# Epoch 38/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.4541 - acc: 0.9093 - val_loss: 0.5470 - val_acc: 0.8802
#
# Epoch 00038: val_acc improved from 0.87940 to 0.88020, saving model to /content/saved_models/cifar10_ResNet18v1_model.038.h5
# Epoch 39/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4534 - acc: 0.9089 - val_loss: 0.5463 - val_acc: 0.8801
#
# Epoch 00039: val_acc did not improve from 0.88020
# Epoch 40/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.4517 - acc: 0.9099 - val_loss: 0.5427 - val_acc: 0.8806
#
# Epoch 00040: val_acc improved from 0.88020 to 0.88060, saving model to /content/saved_models/cifar10_ResNet18v1_model.040.h5
# Epoch 41/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.4484 - acc: 0.9101 - val_loss: 0.5396 - val_acc: 0.8805
#
# Epoch 00041: val_acc did not improve from 0.88060
# Epoch 42/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.4491 - acc: 0.9107 - val_loss: 0.5393 - val_acc: 0.8812
#
# Epoch 00042: val_acc improved from 0.88060 to 0.88120, saving model to /content/saved_models/cifar10_ResNet18v1_model.042.h5
# Epoch 43/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.4480 - acc: 0.9089 - val_loss: 0.5420 - val_acc: 0.8811
#
# Epoch 00043: val_acc did not improve from 0.88120
# Epoch 44/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.4449 - acc: 0.9099 - val_loss: 0.5377 - val_acc: 0.8818
#
# Epoch 00044: val_acc improved from 0.88120 to 0.88180, saving model to /content/saved_models/cifar10_ResNet18v1_model.044.h5
# Epoch 45/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.4442 - acc: 0.9106 - val_loss: 0.5370 - val_acc: 0.8816
#
# Epoch 00045: val_acc did not improve from 0.88180
# Epoch 46/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.4391 - acc: 0.9125 - val_loss: 0.5372 - val_acc: 0.8819
#
# Epoch 00046: val_acc improved from 0.88180 to 0.88190, saving model to /content/saved_models/cifar10_ResNet18v1_model.046.h5
# Epoch 47/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.4399 - acc: 0.9134 - val_loss: 0.5360 - val_acc: 0.8811
#
# Epoch 00047: val_acc did not improve from 0.88190
# Epoch 48/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.4378 - acc: 0.9118 - val_loss: 0.5374 - val_acc: 0.8820
#
# Epoch 00048: val_acc improved from 0.88190 to 0.88200, saving model to /content/saved_models/cifar10_ResNet18v1_model.048.h5
# Epoch 49/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.4362 - acc: 0.9132 - val_loss: 0.5350 - val_acc: 0.8824
#
# Epoch 00049: val_acc improved from 0.88200 to 0.88240, saving model to /content/saved_models/cifar10_ResNet18v1_model.049.h5
# Epoch 50/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.4367 - acc: 0.9126 - val_loss: 0.5324 - val_acc: 0.8831
#
# Epoch 00050: val_acc improved from 0.88240 to 0.88310, saving model to /content/saved_models/cifar10_ResNet18v1_model.050.h5
# 10000/10000 [==============================] - 2s 182us/step
# Test loss: 0.5323592052459717
# Test accuracy: 0.8831

# %% [markdown]
# Let's start with a pretrained VGG model

# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image
import numpy as np
import cv2

# %% [markdown]
# 1.  Loading helper functions
# 2.  Load VGG
# 3. Load Image
# 4. Rescale image to 224x224x3 (VGG's expectation, why?)
# 5. Use expand_dims to convert image to a batch of size 1
# 6. Preprocesing normalizes our input image by subtracting mean RGB values

# %%
model = VGG16(weights="imagenet")
from skimage import io
dog = io.imread("https://upload.wikimedia.org/wikipedia/commons/thumb/1/14/Gatto_europeo4.jpg/250px-Gatto_europeo4.jpg")
dog = cv2.resize(dog, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)
x = image.img_to_array(dog)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %% [markdown]
# 1. We get the predictions for the image
# 2. We take the topmost class index
# 3. Take output from the final convolutional layer

# %%
preds = model.predict(x)
class_idx = np.argmax(preds[0])
print(class_idx)
class_output = model.output[:, class_idx]
last_conv_layer = model.get_layer("block5_conv3")
# Out:
# 281

# %% [markdown]
# 1. Compute the gradient of the class output value with respect to the feature map
# 2. Pool the gradients over all the axies leaving out the channel dimension
# 3. Weigh the output feature map with the computed gradient values

# %%
grads = K.gradients(class_output, last_conv_layer.output)[0]
print(grads.shape)
pooled_grads = K.mean(grads, axis=(0, 1, 2))
print(pooled_grads.shape)
iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

pooled_grads_value, conv_layer_output_value = iterate([x])

for i in range(512):
  conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
# Out:
# (?, 14, 14, 512)
# (512,)

# %% [markdown]
# 1. Average the weighted feature map along the channel dimension resulting in a heat map of size 14x14
# 2. Normalize the heat map to make the values between 0 and 1

# %%
heatmap = np.mean(conv_layer_output_value, axis = -1)
print(conv_layer_output_value.shape)
print(heatmap.shape)
heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)
# Out:
# (14, 14, 512)
# (14, 14)

# %% [markdown]
# Show the results

# %%
heatmap = cv2.resize(heatmap, (dog.shape[1], dog.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
superimposed_img = cv2.addWeighted(dog, 0.5, heatmap, 0.5, 0)
from google.colab.patches import cv2_imshow
cv2_imshow( dog)
cv2_imshow(superimposed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FA2199B6160>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FA2199B6DA0>

# %%
# !pip install keract
# Out:
# Collecting keract
#   Downloading https://files.pythonhosted.org/packages/62/80/216f90188949e4a2c53a62e8799f6ad12d9703284d57785d6036fa43aec5/keract-2.8.5-py3-none-any.whl
# Collecting keras>=2.3.1
#   Downloading https://files.pythonhosted.org/packages/ad/fd/6bfe87920d7f4fd475acd28500a42482b6b84479832bdc0fe9e589a60ceb/Keras-2.3.1-py2.py3-none-any.whl (377kB)
#      |████████████████████████████████| 378kB 12.1MB/s
# Collecting numpy==1.16.2
#   Downloading https://files.pythonhosted.org/packages/35/d5/4f8410ac303e690144f0a0603c4b8fd3b986feb2749c435f7cdbb288f17e/numpy-1.16.2-cp36-cp36m-manylinux1_x86_64.whl (17.3MB)
#      |████████████████████████████████| 17.3MB 66.6MB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras>=2.3.1->keract) (1.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras>=2.3.1->keract) (2.8.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras>=2.3.1->keract) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras>=2.3.1->keract) (1.12.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras>=2.3.1->keract) (1.3.3)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras>=2.3.1->keract) (1.0.8)
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: numpy, keras, keract
#   Found existing installation: numpy 1.17.4
#     Uninstalling numpy-1.17.4:
#       Successfully uninstalled numpy-1.17.4
#   Found existing installation: Keras 2.2.5
#     Uninstalling Keras-2.2.5:
#       Successfully uninstalled Keras-2.2.5
# Successfully installed keract-2.8.5 keras-2.3.1 numpy-1.16.2

# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing.image import img_to_array

model = VGG16()

from PIL import Image
import requests
from io import BytesIO

url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/14/Gatto_europeo4.jpg/250px-Gatto_europeo4.jpg'
response = requests.get(url)
image = Image.open(BytesIO(response.content))
image = image.crop((0, 0, 224, 224))
image = img_to_array(image)
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
image = preprocess_input(image)
yhat = model.predict(image)
label = decode_predictions(yhat)
label = label[0][0]
print('{} ({})'.format(label[1], label[2] * 100))

import keract

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
activations = keract.get_activations(model, image)
first = activations.get('block1_conv1/Relu:0')
keract.display_activations(activations)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 0us/step
# Egyptian_cat (47.48033285140991)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/keract/keract.py in _evaluate(model, nodes_to_evaluate, x, y)
#      29     try:
# ---> 30         return eval_fn(model._feed_inputs + model._feed_targets + model._feed_sample_weights)
#      31     except:
#
# /usr/local/lib/python3.6/dist-packages/keract/keract.py in eval_fn(k_inputs)
#      26     def eval_fn(k_inputs):
# ---> 27         return K.function(k_inputs, nodes_to_evaluate)(model._standardize_user_data(x, y))
#      28
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2978
# -> 2979     Note that `print_tensor` returns a new tensor identical to `x`
#    2980     which should be used in the following code. Otherwise the
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2936     # Returns
# -> 2937         A list of Numpy arrays.
#    2938     """
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#
# InvalidArgumentError: 2 root error(s) found.
#   (0) Invalid argument: transpose expects a vector of size 5. But input(1) is a vector of size 4
# 	 [[{{node block1_conv1_1/convolution-0-TransposeNHWCToNCHW-LayoutOptimizer}}]]
#   (1) Invalid argument: transpose expects a vector of size 5. But input(1) is a vector of size 4
# 	 [[{{node block1_conv1_1/convolution-0-TransposeNHWCToNCHW-LayoutOptimizer}}]]
# 	 [[block5_conv1_1/Relu/_14055]]
# 0 successful operations.
# 0 derived errors ignored.
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-33-380937993c1f> in <module>()
#      27               loss='categorical_crossentropy',
#      28               metrics=['accuracy'])
# ---> 29 activations = keract.get_activations(model, image)
#      30 first = activations.get('block1_conv1/Relu:0')
#      31 keract.display_activations(activations)
#
# /usr/local/lib/python3.6/dist-packages/keract/keract.py in get_activations(model, x, layer_name)
#      96     input_layer_outputs, layer_outputs = [], []
#      97     [input_layer_outputs.append(node) if 'input_' in node.name else layer_outputs.append(node) for node in nodes]
# ---> 98     activations = _evaluate(model, layer_outputs, x, y=None)
#      99     activations_dict = OrderedDict(zip([output.name for output in layer_outputs], activations))
#     100     activations_inputs_dict = OrderedDict(zip([output.name for output in input_layer_outputs], x))
#
# /usr/local/lib/python3.6/dist-packages/keract/keract.py in _evaluate(model, nodes_to_evaluate, x, y)
#      30         return eval_fn(model._feed_inputs + model._feed_targets + model._feed_sample_weights)
#      31     except:
# ---> 32         return eval_fn(model._feed_inputs)
#      33
#      34
#
# /usr/local/lib/python3.6/dist-packages/keract/keract.py in eval_fn(k_inputs)
#      25
#      26     def eval_fn(k_inputs):
# ---> 27         return K.function(k_inputs, nodes_to_evaluate)(model._standardize_user_data(x, y))
#      28
#      29     try:
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977     """Prints `message` and the tensor value when evaluated.
#    2978
# -> 2979     Note that `print_tensor` returns a new tensor identical to `x`
#    2980     which should be used in the following code. Otherwise the
#    2981     print operation is not taken into account during evaluation.
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935
#    2936     # Returns
# -> 2937         A list of Numpy arrays.
#    2938     """
#    2939     return tf_keras_backend.batch_get_value(ops)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# InvalidArgumentError: 2 root error(s) found.
#   (0) Invalid argument: transpose expects a vector of size 5. But input(1) is a vector of size 4
# 	 [[{{node block1_conv1_1/convolution-0-TransposeNHWCToNCHW-LayoutOptimizer}}]]
# 	 [[block5_conv1_1/Relu/_14105]]
#   (1) Invalid argument: transpose expects a vector of size 5. But input(1) is a vector of size 4
# 	 [[{{node block1_conv1_1/convolution-0-TransposeNHWCToNCHW-LayoutOptimizer}}]]
# 0 successful operations.
# 0 derived errors ignored.
